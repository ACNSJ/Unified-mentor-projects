# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.ensemble import RandomForestRegressor,ExtraTreesRegressor
import pandas as pd

# %%
#loading CSV file
df=pd.read_csv('dataset.csv')

df
# Out:
#                                                 name  \
# 0                       2024 Jeep Wagoneer Series II
# 1                    2024 Jeep Grand Cherokee Laredo
# 2                           2024 GMC Yukon XL Denali
# 3                         2023 Dodge Durango Pursuit
# 4                              2024 RAM 3500 Laramie
# ...                                              ...
# 997   2024 Mercedes-Benz Sprinter 2500 Standard Roof
# 998           2024 Dodge Hornet Hornet R/T Plus Eawd
# 999                          2024 Jeep Wagoneer Base
# 1000           2024 Nissan Murano SV Intelligent AWD
# 1001                2024 Chevrolet Silverado 2500 WT
#
#                                             description           make  \
# 0     \n      \n        Heated Leather Seats, Nav Sy...           Jeep
# 1     Al West is committed to offering every custome...           Jeep
# 2                                                   NaN            GMC
# ...

# %%
#Check for duplicates
x=df.duplicated()
print("Duplicated :",x.sum())

#drop duplicates

df=df.drop_duplicates()

print(df.duplicated().sum())


#drop unnecessary columns
df=df.drop(df.columns[[0,1,3,4,6]],axis=1)
df
# Out:
# Duplicated : 24
# 0
#                make    price  cylinders      fuel  mileage       transmission  \
# 0              Jeep  74600.0        6.0  Gasoline     10.0  8-Speed Automatic
# 1              Jeep  50170.0        6.0  Gasoline      1.0  8-Speed Automatic
# 2               GMC  96410.0        8.0  Gasoline      0.0          Automatic
# 3             Dodge  46835.0        8.0  Gasoline     32.0  8-Speed Automatic
# 4               RAM  81663.0        6.0    Diesel     10.0  6-Speed Automatic
# ...             ...      ...        ...       ...      ...                ...
# 996             RAM  69315.0        6.0    Diesel      0.0          Automatic
# 997   Mercedes-Benz  59037.0        4.0    Diesel     10.0  9-Speed Automatic
# 999            Jeep  69085.0        6.0  Gasoline     20.0  8-Speed Automatic
# 1000         Nissan  43495.0        6.0  Gasoline      6.0          Automatic
# 1001      Chevrolet  48995.0        8.0  Gasoline     31.0          Automatic
#
# ...

# %%
#Check for null values

x=df.notnull().sum()
print(x)

#drop null values

df=df.dropna()

df=df.drop(df.columns[[9,10]],axis=1)
df
# Out:
# make              978
# price             955
# cylinders         875
# fuel              971
# mileage           946
# transmission      976
# trim              977
# body              975
# doors             971
# exterior_color    973
# interior_color    940
# drivetrain        978
# dtype: int64
#                make    price  cylinders      fuel  mileage       transmission  \
# 0              Jeep  74600.0        6.0  Gasoline     10.0  8-Speed Automatic
# 1              Jeep  50170.0        6.0  Gasoline      1.0  8-Speed Automatic
# 2               GMC  96410.0        8.0  Gasoline      0.0          Automatic
# 3             Dodge  46835.0        8.0  Gasoline     32.0  8-Speed Automatic
# 4               RAM  81663.0        6.0    Diesel     10.0  6-Speed Automatic
# ...             ...      ...        ...       ...      ...                ...
# 996             RAM  69315.0        6.0    Diesel      0.0          Automatic
# ...

# %%
from sklearn.preprocessing import LabelEncoder

lb_body=LabelEncoder()
lb_drivetrain=LabelEncoder()
lb_fuel=LabelEncoder()
lb_make=LabelEncoder()

df=df.drop(df.columns[[5,6,8]],axis=1)

df['body']=lb_body.fit_transform(df['body'])
df['drivetrain']=lb_drivetrain.fit_transform(df['drivetrain'])
df['fuel']=lb_fuel.fit_transform(df['fuel'])
df['make']=lb_make.fit_transform(df['make'])

print(lb_body.classes_,"\n",lb_drivetrain.classes_,"\n",lb_fuel.classes_,"\n",lb_make.classes_,"\n")

df
# Out:
# ['Cargo Van' 'Convertible' 'Hatchback' 'Minivan' 'Passenger Van'
#  'Pickup Truck' 'SUV' 'Sedan']
#  ['All-wheel Drive' 'Four-wheel Drive' 'Front-wheel Drive'
#  'Rear-wheel Drive']
#  ['Diesel' 'Diesel (B20 capable)' 'E85 Flex Fuel' 'Electric' 'Gasoline'
#  'Hybrid' 'PHEV Hybrid Fuel']
#  ['Audi' 'BMW' 'Buick' 'Cadillac' 'Chevrolet' 'Chrysler' 'Dodge' 'Ford'
#  'GMC' 'Honda' 'Hyundai' 'INFINITI' 'Jeep' 'Kia' 'Land Rover' 'Lexus'
#  'Lincoln' 'Mazda' 'Mercedes-Benz' 'Nissan' 'RAM' 'Subaru' 'Toyota'
#  'Volkswagen' 'Volvo']
#       make    price  cylinders  fuel  mileage  body  drivetrain
# 0       12  74600.0        6.0     4     10.0     6           1
# 1       12  50170.0        6.0     4      1.0     6           1
# 2        8  96410.0        8.0     4      0.0     6           1
# 3        6  46835.0        8.0     4     32.0     6           0
# 4       20  81663.0        6.0     0     10.0     5           1
# ...    ...      ...        ...   ...      ...   ...         ...
# ...

# %%
#Splitting the dataset
ds=df.to_numpy()

y=ds[:,1]

df=df.drop(df.columns[[1]],axis=1)
ds=df.to_numpy()

X=ds


from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0,shuffle=True)

y.shape
# Out:
# (781,)

# %%
#Model Training
model=RandomForestRegressor()
model.fit(X_train,y_train)
# Out:
# RandomForestRegressor()

# %%
from sklearn.metrics import mean_squared_error,r2_score

y_pred=model.predict(X_test)

mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred) 
print(f'Mean Squared Error: {mse}') 
print(f'R-squared: {r2}')

import pickle

with open('price_model.pkl', 'wb') as file: pickle.dump(model, file)
# Out:
# Mean Squared Error: 119724218.85470778
# R-squared: 0.6044892960284172
